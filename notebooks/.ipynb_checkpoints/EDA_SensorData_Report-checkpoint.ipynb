# %% [markdown]
# # 📊 EDA Report – IoT Sensor Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import os
# %matplotlib inline

file_path = Path("..data/merged_data")
# Load CSVs
files = {
    "Stadtteilbüro_Siemensstadt": "Stadtteilbüro_Siemensstadt.csv",
    "Station_Kaiser": "Station_Kaiser.csv",
    "PANGAEAs_SenseBox": "PANGAEAs_SenseBox.csv"
}
print(os.getcwd())
dataframes = {}

# for path in file_path.iterdir():
    # files.items():
    # df = pd.read_csv(path)
#     df['timestamp'] = pd.to_datetime(df['timestamp'])
#     df = df.sort_values('timestamp')
#     df.set_index('timestamp', inplace=True)
#     dataframes[name] = df
# Out:
# /home/jonas-limpert/Projects/EnviroSentinel/notebooks/.ipynb_checkpoints

# %% [markdown]
# ## 📋 Summary Statistics

# %%
summary = []
for name, df in dataframes.items():
    info = {
        "Station": name,
        "Start": df.index.min(),
        "End": df.index.max(),
        "Total Rows": len(df),
        "Duplicates": df.index.duplicated().sum(),
        "Mean Temperature": df["value_Temperatur"].mean(),
        "Mean PM2.5": df["value_PM2.5"].mean(),
        "Mean PM10": df["value_PM10"].mean(),
    }
    summary.append(info)

pd.DataFrame(summary)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## 🌡️ Temperature Over Time

# %%
plt.figure(figsize=(14, 6))
for name, df in dataframes.items():
    df['value_Temperatur'].plot(label=name)
plt.title("Temperature Over Time")
plt.xlabel("Timestamp")
plt.ylabel("Temperature (°C)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_337308/2375843643.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ## 🌫️ PM2.5 Over Time

# %%
plt.figure(figsize=(14, 6))
for name, df in dataframes.items():
    df['value_PM2.5'].plot(label=name)
plt.title("PM2.5 Over Time")
plt.xlabel("Timestamp")
plt.ylabel("PM2.5 (µg/m³)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_337308/790824447.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ## 🌫️ PM10 Over Time

# %%
plt.figure(figsize=(14, 6))
for name, df in dataframes.items():
    df['value_PM10'].plot(label=name)
plt.title("PM10 Over Time")
plt.xlabel("Timestamp")
plt.ylabel("PM10 (µg/m³)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_337308/2312960739.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ## 📊 Histograms of Sensor Values

# %%
for metric in ['value_Temperatur', 'value_PM2.5', 'value_PM10']:
    plt.figure(figsize=(14, 6))
    for name, df in dataframes.items():
        sns.histplot(df[metric], kde=True, label=name, stat="density", bins=50, element="step")
    plt.title(f"Distribution of {metric}")
    plt.xlabel(metric)
    plt.ylabel("Density")
    plt.legend()
    plt.show()
# Out:
# /tmp/ipykernel_337308/2004736608.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ## 🧯 Missing Value Heatmaps

# %%
for name, df in dataframes.items():
    plt.figure(figsize=(14, 2))
    sns.heatmap(df.isnull(), cbar=False)
    plt.title(f"Missing Value Map – {name}")
    plt.show()

# %% [markdown]
# ## 🔗 Correlation Matrices

# %%
for name, df in dataframes.items():
    plt.figure(figsize=(10, 8))
    corr = df.corr()
    sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
    plt.title(f"Sensor Correlation Matrix – {name}")
    plt.show()
